# %%
import ROOT
# Out:
# Welcome to JupyROOT 6.22/06

# %%
fasym = ROOT.TFile("/work/clas12/users/gmat/CLAS12Analysis/data/rg-a/july18/asymmetry.root","READ")

# %%
c = ROOT.TCanvas("c","c",800,600)
tasym = fasym.Get("sideband_Mdihadron_sig_1")
tasym.Draw("APE")
tasym.GetXaxis().SetRangeUser(0.3,1.3)
tasym.GetYaxis().SetRangeUser(-0.06,0.06)
c.Draw()
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c

# %%
f = ROOT.TFile("/work/clas12/users/gmat/CLAS12Analysis/data/rg-a/july18/sideband_bin_Mdihadron_0.300000_0.442857/sidebandMethod.root","READ")
f.ls()
# Out:
# TFile**		/work/clas12/users/gmat/CLAS12Analysis/data/rg-a/july18/sideband_bin_Mdihadron_0.300000_0.442857/sidebandMethod.root
#  TFile*		/work/clas12/users/gmat/CLAS12Analysis/data/rg-a/july18/sideband_bin_Mdihadron_0.300000_0.442857/sidebandMethod.root
#   KEY: TTree	tree;1	Sideband Method Related Variables
#   KEY: TF1	f_diphoton_sig;1	gaus(0)+pol4(3)
#   KEY: TF2	f_sigbg;1	[0]*sin(2*x-2*y)+[1]*sin(x-y)+[2]*sin(-x+2*y)+[3]*sin(y)+[4]*sin(x)+[5]*sin(2*x-y)+[6]*sin(3*x-2*y)
#   KEY: TF2	f_bg;1	[0]*sin(2*x-2*y)+[1]*sin(x-y)+[2]*sin(-x+2*y)+[3]*sin(y)+[4]*sin(x)+[5]*sin(2*x-y)+[6]*sin(3*x-2*y)
#   KEY: TH1F	h1_sbnd;1

# %%
c = ROOT.TCanvas("c","c",800,600)
h = f.Get("h1_sbnd")
#fit_sig = f.Get("f_diphoton_sig")
fit = ROOT.TF1("fit","gaus(0)+pol4(3)",0.08,0.28)
fit.SetParameters(100,0.13,0.01,1,1,1,1,1)
fit.SetParLimits(1,0.128,0.135)
fit.SetParLimits(2,0.001,0.2)
h.Fit(fit,"SR")
#print(fit_sig.GetParameter(2))
fit.Draw("same")
#h.Draw("hist same")
#fit_sig.Draw("same")
c.Draw()
# Out:
#  FCN=213.717 FROM MIGRAD    STATUS=CONVERGED     671 CALLS         672 TOTAL
#                      EDM=5.40057e-07    STRATEGY= 1  ERROR MATRIX UNCERTAINTY   0.9 per cent
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  p0           3.84498e-02   1.82831e-04  -2.15911e-06  -2.16150e+00
#    2  p1           1.32053e-01   5.03508e-05   3.32544e-04   9.40293e-03
#    3  p2           1.26279e-02   7.11331e-05  -2.72144e-07  -1.80691e-02
#    4  p3           1.00431e-02   3.73579e-03  -4.65558e-05  -2.77577e+01
#    5  p4          -3.52202e-02   9.06409e-02   1.08106e-03  -3.79664e+00
#    6  p5           1.76826e+00   7.55977e-01  -8.62168e-03  -5.08341e-01
#    7  p6          -1.22641e+01   2.64721e+00   2.88788e-02  -5.97930e-02
#    8  p7           2.13056e+01   3.33660e+00  -3.48445e-02  -4.25405e-03
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c

# %%
fit = ROOT.TF1("f1","pol4",0,1)

# %%
fit.GetNpar()
# Out:
# 5

# %%
f = ROOT.TFile("/volatile/clas12/users/gmat/clas12analysis.sidis.data/rg-a/july14/merged_july14.root","READ")
f.ls()
# Out:
# TFile**		/volatile/clas12/users/gmat/clas12analysis.sidis.data/rg-a/july14/merged_july14.root
#  TFile*		/volatile/clas12/users/gmat/clas12analysis.sidis.data/rg-a/july14/merged_july14.root
#   KEY: TTree	tree_reco;2	A Tree with *reconstructred* event and particle information
#   KEY: TTree	tree_postprocess;2	Tree created after all hipo events are filtered
#   KEY: TTree	bin_x_0.100000_0.130000;1
#   KEY: TTree	bin_x_0.130000_0.160000;1
#   KEY: TTree	bin_x_0.160000_0.190000;1
#   KEY: TTree	bin_x_0.190000_0.235000;1
#   KEY: TTree	bin_x_0.235000_0.300000;1
#   KEY: TTree	bin_x_0.300000_0.500000;2
#   KEY: TTree	bin_x_0.300000_0.500000;1
#   KEY: TTree	bin_z_0.350000_0.430000;1
#   KEY: TTree	bin_z_0.430000_0.490000;1
#   KEY: TTree	bin_z_0.490000_0.550000;1
#   KEY: TTree	bin_z_0.550000_0.620000;1
#   KEY: TTree	bin_z_0.620000_0.700000;1
#   KEY: TTree	bin_z_0.700000_0.830000;2
#   KEY: TTree	bin_z_0.700000_0.830000;1
#   KEY: TTree	bin_Mdihadron_0.300000_0.442857;1
#   KEY: TTree	bin_Mdihadron_0.442857_0.585714;1
#   KEY: TTree	bin_Mdihadron_0.585714_0.728571;1
#   KEY: TTree	bin_Mdihadron_0.728571_0.871429;1
#   KEY: TTree	bin_Mdihadron_0.871429_1.014286;1
#   KEY: TTree	bin_Mdihadron_1.014286_1.157143;1

# %%
t = f.Get("bin_x_0.130000_0.160000")
c = ROOT.TCanvas("c","c",800,600)
t.Draw("Mdiphoton")
c.Draw()
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c

# %%
f = ROOT.TFile("/volatile/clas12/users/gmat/clas12analysis.sidis.data/rg-a/july14/sideband_bin_x_0.130000_0.160000/sidebandMethod.root","READ")
f.ls()
# Out:
# TFile**		/volatile/clas12/users/gmat/clas12analysis.sidis.data/rg-a/july14/sideband_bin_x_0.130000_0.160000/sidebandMethod.root
#  TFile*		/volatile/clas12/users/gmat/clas12analysis.sidis.data/rg-a/july14/sideband_bin_x_0.130000_0.160000/sidebandMethod.root
#   KEY: TTree	tree;1	Sideband Method Related Variables
#   KEY: TF1	f_diphoton_sig;1	gaus(0)+pol4(3)
#   KEY: TF2	f_sigbg;1	[0]*sin(2*x-2*y)+[1]*sin(x-y)+[2]*sin(-x+2*y)+[3]*sin(y)+[4]*sin(x)+[5]*sin(2*x-y)+[6]*sin(3*x-2*y)
#   KEY: TF2	f_bg;1	[0]*sin(2*x-2*y)+[1]*sin(x-y)+[2]*sin(-x+2*y)+[3]*sin(y)+[4]*sin(x)+[5]*sin(2*x-y)+[6]*sin(3*x-2*y)
#   KEY: TH1F	h1_sbnd;1

# %%
ff = f.Get("f_diphoton_sig")
hh = f.Get("h1_sbnd")
ff.GetChisquare()/ff.GetNDF()
# Out:
# 2.8993846894625337

# %%
ff.Draw()
hh.Draw("same hist")
c.Draw()

# %%
ff.GetBinContent(2)
ff.GetBinCenter(16)
# Out:
# 0.0775

# %%
f = ROOT.TFile("/volatile/clas12/users/gmat/clas12analysis.sidis.data/rg-a/july14/merged_july14.root","READ")
f.ls()
# Out:
# TFile**		/volatile/clas12/users/gmat/clas12analysis.sidis.data/rg-a/july14/merged_july14.root
#  TFile*		/volatile/clas12/users/gmat/clas12analysis.sidis.data/rg-a/july14/merged_july14.root
#   KEY: TTree	tree_reco;2	A Tree with *reconstructred* event and particle information
#   KEY: TTree	tree_postprocess;2	Tree created after all hipo events are filtered
#   KEY: TTree	bin_x_0.100000_0.130000;1
#   KEY: TTree	bin_x_0.130000_0.160000;1
#   KEY: TTree	bin_x_0.160000_0.190000;1
#   KEY: TTree	bin_x_0.190000_0.235000;1
#   KEY: TTree	bin_x_0.235000_0.300000;1
#   KEY: TTree	bin_x_0.300000_0.500000;2
#   KEY: TTree	bin_x_0.300000_0.500000;1
#   KEY: TTree	bin_z_0.350000_0.430000;1
#   KEY: TTree	bin_z_0.430000_0.490000;1
#   KEY: TTree	bin_z_0.490000_0.550000;1
#   KEY: TTree	bin_z_0.550000_0.620000;1
#   KEY: TTree	bin_z_0.620000_0.700000;1
#   KEY: TTree	bin_z_0.700000_0.830000;2
#   KEY: TTree	bin_z_0.700000_0.830000;1
#   KEY: TTree	bin_Mdihadron_0.300000_0.442857;1
#   KEY: TTree	bin_Mdihadron_0.442857_0.585714;1
#   KEY: TTree	bin_Mdihadron_0.585714_0.728571;1
#   KEY: TTree	bin_Mdihadron_0.728571_0.871429;1
#   KEY: TTree	bin_Mdihadron_0.871429_1.014286;1
#   KEY: TTree	bin_Mdihadron_1.014286_1.157143;1

# %%
t = f.Get("tree_postprocess")

# %%
t.Draw("Mdiphoton:Mdihadron","Mdihadron>0.5&&Mdihadron<1","colz")
c.Draw()

# %%
t.Draw("Mdihadron","Mdiphoton>0.108 && Mdiphoton < 0.16")
c.Draw()
