# %%
import ROOT
# Out:
# Welcome to JupyROOT 6.22/06

# %%
tfile = ROOT.TFile("/volatile/clas12/users/gmat/clas12analysis.sidis.data/rg-a/aug23/sideband_bin_Mdihadron_0.300000_0.442857/sidebandMethod.root","READ")
tfile.ls()
# Out:
# TFile**		/volatile/clas12/users/gmat/clas12analysis.sidis.data/rg-a/aug23/sideband_bin_Mdihadron_0.300000_0.442857/sidebandMethod.root
#  TFile*		/volatile/clas12/users/gmat/clas12analysis.sidis.data/rg-a/aug23/sideband_bin_Mdihadron_0.300000_0.442857/sidebandMethod.root
#   KEY: TTree	tree;1	Sideband Method Related Variables
#   KEY: TF1	f_diphoton_sig;1	gaus(0)+pol4(3)
#   KEY: TF2	f_sigbg;1	[0]*sin(2*x-2*y)+[1]*sin(x-y)+[2]*sin(-x+2*y)+[3]*sin(y)+[4]*sin(x)+[5]*sin(2*x-y)+[6]*sin(3*x-2*y)
#   KEY: TF2	f_bg;1	[0]*sin(2*x-2*y)+[1]*sin(x-y)+[2]*sin(-x+2*y)+[3]*sin(y)+[4]*sin(x)+[5]*sin(2*x-y)+[6]*sin(3*x-2*y)
#   KEY: TH1F	h1_sbnd;1

# %%
h = tfile.Get("h1_sbnd")
f = ROOT.TF1("f","gaus(0)+pol4(3)",0.08,0.4)
f.SetParameters(1,0.13,0.01,1,1,1,1,1)
f.SetParLimits(1,0.128,0.135)
f.SetParLimits(2,0.001,0.07)
c = ROOT.TCanvas("c","c",800,800)
h.Draw()
h.Fit(f,"SR")
f.Draw("same")
c.Draw()
# Out:
#  FCN=245.522 FROM MIGRAD    STATUS=CONVERGED    1639 CALLS        1640 TOTAL
#                      EDM=9.38747e-08    STRATEGY= 1  ERROR MATRIX UNCERTAINTY   0.8 per cent
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  p0           3.79987e-02   1.49735e-04   1.09381e-07   2.34300e-01
#    2  p1           1.32075e-01   4.91011e-05   4.57177e-06  -6.23930e-03
#    3  p2           1.24108e-02   5.01803e-05  -1.24877e-06   1.56057e+00
#    4  p3          -3.89901e-03   2.86208e-04  -1.49854e-07  -1.07725e+01
#    5  p4           2.94294e-01   3.46759e-03   1.49506e-06   1.63980e+01
#    6  p5          -8.72687e-01   6.22081e-03  -2.37836e-06  -1.08737e+01
#    7  p6          -3.45817e+00   4.16802e-02  -1.65858e-05   2.36179e+00
#    8  p7           1.08069e+01   1.13413e-01   4.52645e-05  -2.43323e-01
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c

# %%
h.Draw()
h.Fit(f,"SR")
f.Draw("same")
c.Draw()
# Out:
#  FCN=74002.8 FROM MIGRAD    STATUS=CALL LIMIT   2134 CALLS        2135 TOTAL
#                      EDM=35.6076    STRATEGY= 1  ERROR MATRIX UNCERTAINTY  36.2 per cent
#   EXT PARAMETER                APPROXIMATE        STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  p0           4.68253e-02   3.08645e-05   1.57161e-05   1.07056e+06
#    2  p1           1.28003e-01   2.62226e-06   6.53061e-03   2.11438e+02
#    3  p2           8.08522e-02   3.45011e-04  -8.00129e-03   1.15510e+05
#    4  p3          -3.09966e-02   1.57055e-04  -2.95824e-04   4.08615e+06
#    5  p4           5.49987e-02   1.07707e-03   2.36701e-03   1.21169e+06
#    6  p5          -7.72160e-02   1.29225e-03   2.52124e-03   3.50818e+05
#    7  p6           6.61134e-01   7.78693e-03   1.71901e-02   1.03448e+05
#    8  p7          -1.38358e-01   4.83504e-02  -1.09316e-01   3.13785e+04
# Warning in <Fit>: Abnormal termination of minimization.

# %%
h.Draw()
h.Fit(f,"SR")
f.Draw("same")
c.Draw()
# Out:
#  FCN=249.239 FROM MIGRAD    STATUS=CONVERGED     961 CALLS         962 TOTAL
#                      EDM=1.48877e-07    STRATEGY= 1  ERROR MATRIX UNCERTAINTY   2.0 per cent
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  p0           3.79686e-02   1.52138e-04   5.52336e-07   8.70171e-01
#    2  p1           1.32076e-01   4.94087e-05   3.70304e-05   5.04852e-03
#    3  p2           1.23956e-02   5.12393e-05  -3.64531e-06   4.71033e-01
#    4  p3          -4.78803e-03   2.90526e-04   1.55405e-07  -2.06623e+01
#    5  p4           3.15010e-01   3.61742e-03   3.79732e-07   1.03255e+01
#    6  p5          -1.03565e+00   7.73947e-03  -4.58977e-06  -1.25362e+01
#    7  p6          -2.92603e+00   3.57631e-02  -1.19551e-05   2.52031e+00
#    8  p7           1.01862e+01   1.05852e-01   5.82287e-05  -4.64883e-01
