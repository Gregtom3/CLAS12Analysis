# %%
import ROOT, shutil
ROOT.gROOT.ProcessLine(".x $BRUFIT/macros/LoadBru.C")
pwd = ROOT.gSystem.pwd()

# %% [markdown]
# # sPlot with Gaussian signal and Polynomial background

# %% [markdown]
# First, we must create a new, weighted phi asymmetry observable fit using "RooFitSkeleton". This is accomplished by first **make-ing** the brufit repository using JLab's Jupyterhub (not via ssh). Then, you must 'cd' into the macros directory, run **root**, and execute the line **.L LoadBru.C**. Then, you can safely run the necessary commands to generate the asymmetry observable. See (https://github.com/dglazier/brufit/tree/dev/tutorials/WeightedObservable) for more details on that.

# %% [markdown]
# Create the sPlot fit manager and set the ouput directory for fit results, plots and weights

# %%
splot = ROOT.sPlot()
try:
    shutil.rmtree(pwd+"/outSplot")
except OSError as e:
    print(e)
splot.SetUp().SetOutDir(pwd+"/outSplot")
splot.SetRedirectOutput() # Forces minimal output when fitting diphoton peaks

# %% [markdown]
# Load up the diphoton mass fitting variable, the exact variable responsible for identifying background from signal

# %%
splot.SetUp().LoadVariable("Mdiphoton[0.08,0.22]");
splot.SetUp().SetIDBranchName("fidmerge");

# %% [markdown]
# Create the basic signal for the diphoton mass

# %%
splot.SetUp().FactoryPDF("Gaussian::Signal(Mdiphoton,#mu[0.131,0.129,0.136],#sigma[0.1,0.001,0.2])")
splot.SetUp().LoadSpeciesPDF("Signal")

# %% [markdown]
# Create the basic background fit (4th order chebychev)

# %%
#splot.SetUp().FactoryPDF("Polynomial::BG(Mdiphoton,{a0,a1[1,-100000,100000],a2[1,-100000,100000],a3[1,-100000,100000]})")
splot.SetUp().FactoryPDF("Polynomial::BG(Mdiphoton,{a0[0.1,-100,100],a1[0.1,-100,100],a2[0.1,-100,100],a3[0.1,-100,100]})")
splot.SetUp().LoadSpeciesPDF("BG",1)

# %% [markdown]
# Bin the data 6 times in {Mh}

# %%
splot.Bins().LoadBinVar("Mdihadron",6,0.3,1.3)

# %% [markdown]
# Load data with TTree name and file location
#
# Can try to suppress output in Binner.cpp

# %%
splot.LoadData("tree_postprocess","/work/clas12/users/gmat/CLAS12Analysis/data/rg-a/june8.root")
# Out:
# Binner tree_postprocess /work/clas12/users/gmat/CLAS12Analysis/data/rg-a/june8.root PyROOT
# SplitData /w/hallb-scshelf2102/clas12/users/gmat/CLAS12Analysis/macros/dihadron_analysis/rg-a/outSplot/ 0
# Bins::RunBinTree Running bins from 0 to 6
# Constructing Bin Tree /w/hallb-scshelf2102/clas12/users/gmat/CLAS12Analysis/macros/dihadron_analysis/rg-a/outSplot//Mdihadron0.38_/TreeData
# Constructing Bin Tree /w/hallb-scshelf2102/clas12/users/gmat/CLAS12Analysis/macros/dihadron_analysis/rg-a/outSplot//Mdihadron0.55_/TreeData
# Constructing Bin Tree /w/hallb-scshelf2102/clas12/users/gmat/CLAS12Analysis/macros/dihadron_analysis/rg-a/outSplot//Mdihadron0.72_/TreeData
# Constructing Bin Tree /w/hallb-scshelf2102/clas12/users/gmat/CLAS12Analysis/macros/dihadron_analysis/rg-a/outSplot//Mdihadron0.88_/TreeData
# Constructing Bin Tree /w/hallb-scshelf2102/clas12/users/gmat/CLAS12Analysis/macros/dihadron_analysis/rg-a/outSplot//Mdihadron1.05_/TreeData
# Constructing Bin Tree /w/hallb-scshelf2102/clas12/users/gmat/CLAS12Analysis/macros/dihadron_analysis/rg-a/outSplot//Mdihadron1.22_/TreeData
# On event 0 = 0%
# On event 100000 = 3.283%
# On event 200000 = 6.566%
# On event 300000 = 9.849%
# On event 400000 = 13.132%
# On event 500000 = 16.415%
# On event 600000 = 19.698%
# On event 700000 = 22.981%
# On event 800000 = 26.264%
# On event 900000 = 29.547%
# On event 1000000 = 32.83%
# On event 1100000 = 36.113%
# On event 1200000 = 39.396%
# On event 1300000 = 42.679%
# On event 1400000 = 45.962%
# On event 1500000 = 49.245%
# On event 1600000 = 52.528%
# On event 1700000 = 55.811%
# On event 1800000 = 59.094%
# On event 1900000 = 62.377%
# On event 2000000 = 65.66%
# On event 2100000 = 68.943%
# On event 2200000 = 72.226%
# On event 2300000 = 75.509%
# On event 2400000 = 78.792%
# On event 2500000 = 82.075%
# On event 2600000 = 85.358%
# On event 2700000 = 88.641%
# On event 2800000 = 91.924%
# On event 2900000 = 95.207%
# On event 3000000 = 98.49%
# BinTree::Save() /w/hallb-scshelf2102/clas12/users/gmat/CLAS12Analysis/macros/dihadron_analysis/rg-a/outSplot//Mdihadron0.38_/TreeData
# BinTree::Save() /w/hallb-scshelf2102/clas12/users/gmat/CLAS12Analysis/macros/dihadron_analysis/rg-a/outSplot//Mdihadron0.55_/TreeData
# BinTree::Save() /w/hallb-scshelf2102/clas12/users/gmat/CLAS12Analysis/macros/dihadron_analysis/rg-a/outSplot//Mdihadron0.72_/TreeData
# BinTree::Save() /w/hallb-scshelf2102/clas12/users/gmat/CLAS12Analysis/macros/dihadron_analysis/rg-a/outSplot//Mdihadron0.88_/TreeData
# BinTree::Save() /w/hallb-scshelf2102/clas12/users/gmat/CLAS12Analysis/macros/dihadron_analysis/rg-a/outSplot//Mdihadron1.05_/TreeData
# BinTree::Save() /w/hallb-scshelf2102/clas12/users/gmat/CLAS12Analysis/macros/dihadron_analysis/rg-a/outSplot//Mdihadron1.22_/TreeData
# Binner tree_postprocess /work/clas12/users/gmat/CLAS12Analysis/data/rg-a/june8.root done PyROOT
# FiledTree::~FiledTree()  tree name tree_postprocess 3045996 /work/clas12/users/gmat/CLAS12Analysis/data/rg-a/june8.root
# DataEvents::Load tree_postprocess with 6 files
# Info in <HS::FIT::Bins:: Bins::Save()>:  Saving HSBins to /w/hallb-scshelf2102/clas12/users/gmat/CLAS12Analysis/macros/dihadron_analysis/rg-a/outSplot/DataBinsConfig.root

# %%
ROOT.Here.Go(splot)
# Out:
# FitManager::RedirectOutput text ouput will be sent to file /w/hallb-scshelf2102/clas12/users/gmat/CLAS12Analysis/macros/dihadron_analysis/rg-a/outSplot/logRooFit0.txt
# RooArgList:: = (#mu,#sigma,a0,a1,a2,a3)
# RooArgList:: = (Yld_Signal,Yld_BG)
# REMOVE FILEDTREE 0
# REMOVED FILEDTREE
# FitManager::RedirectOutput text ouput will be sent to file /w/hallb-scshelf2102/clas12/users/gmat/CLAS12Analysis/macros/dihadron_analysis/rg-a/outSplot/logRooFit1.txt
# RooArgList:: = (#mu,#sigma,a0,a1,a2,a3)
# RooArgList:: = (Yld_Signal,Yld_BG)
# REMOVE FILEDTREE 0
# REMOVED FILEDTREE
# FitManager::RedirectOutput text ouput will be sent to file /w/hallb-scshelf2102/clas12/users/gmat/CLAS12Analysis/macros/dihadron_analysis/rg-a/outSplot/logRooFit2.txt
# RooArgList:: = (#mu,#sigma,a0,a1,a2,a3)
# RooArgList:: = (Yld_Signal,Yld_BG)
# REMOVE FILEDTREE 0
# REMOVED FILEDTREE
# FitManager::RedirectOutput text ouput will be sent to file /w/hallb-scshelf2102/clas12/users/gmat/CLAS12Analysis/macros/dihadron_analysis/rg-a/outSplot/logRooFit3.txt
# RooArgList:: = (#mu,#sigma,a0,a1,a2,a3)
# RooArgList:: = (Yld_Signal,Yld_BG)
# REMOVE FILEDTREE 0
# REMOVED FILEDTREE
# FitManager::RedirectOutput text ouput will be sent to file /w/hallb-scshelf2102/clas12/users/gmat/CLAS12Analysis/macros/dihadron_analysis/rg-a/outSplot/logRooFit4.txt
# RooArgList:: = (#mu,#sigma,a0,a1,a2,a3)
# RooArgList:: = (Yld_Signal,Yld_BG)
# REMOVE FILEDTREE 0
# REMOVED FILEDTREE
# FitManager::RedirectOutput text ouput will be sent to file /w/hallb-scshelf2102/clas12/users/gmat/CLAS12Analysis/macros/dihadron_analysis/rg-a/outSplot/logRooFit5.txt
# RooArgList:: = (#mu,#sigma,a0,a1,a2,a3)
# RooArgList:: = (Yld_Signal,Yld_BG)
# REMOVE FILEDTREE 0
# REMOVED FILEDTREE

# %%
splot.MergeWeights()
# Out:
# <cppyy.gbl.HS.FIT.Weights object at 0x55a684324860 held by std::unique_ptr<HS::FIT::Weights,default_delete<HS::FIT::Weights> > at 0x55a68442faa0>
# Weights::Merge Merging Weights* in directory /w/hallb-scshelf2102/clas12/users/gmat/CLAS12Analysis/macros/dihadron_analysis/rg-a/outSplot
# Insert species BG 0 0
# Insert species Signal 1 0
# Weights::SortWeights() Clone tree to save
# Weights HSsWeights contains 1654237 events associated file is /w/hallb-scshelf2102/clas12/users/gmat/CLAS12Analysis/macros/dihadron_analysis/rg-a/outSplot//Tweights.root
# ID branch name : fidmerge
# Species are :
# BG
# Signal
# The first ten entries are :
# 1 -0.274613 1.27462
# 5 -0.145053 1.14505
# 6 1.01966 -0.0196664
# 8 1.60401 -0.604013
# 9 0.0320905 0.967912
# 10 -0.114136 1.11414
# 11 -0.0893609 1.08936
# 12 -0.0914785 1.09148
# 15 -0.0204848 1.02049
# 16 1.49279 -0.492791
# These weights are combined from :
# Mdihadron0.38_
# Mdihadron0.88_
# Mdihadron1.22_
# Mdihadron0.55_
# Mdihadron0.72_
# Mdihadron1.05_

# %%
splot.saveWeightedTree(pwd+"/outSplot/DataWeightedTree.root")
# Out:
# Weights::Merge Merging Weights* in directory /w/hallb-scshelf2102/clas12/users/gmat/CLAS12Analysis/macros/dihadron_analysis/rg-a/outSplot
# Insert species BG 0 0
# Insert species Signal 1 0
# Weights::SortWeights() Clone tree to save
# Weights HSsWeights contains 1654237 events associated file is /w/hallb-scshelf2102/clas12/users/gmat/CLAS12Analysis/macros/dihadron_analysis/rg-a/outSplot//Tweights.root
# ID branch name : fidmerge
# Species are :
# BG
# Signal
# The first ten entries are :
# 1 -0.274613 1.27462
# 5 -0.145053 1.14505
# 6 1.01966 -0.0196664
# 8 1.60401 -0.604013
# 9 0.0320905 0.967912
# 10 -0.114136 1.11414
# 11 -0.0893609 1.08936
# 12 -0.0914785 1.09148
# 15 -0.0204848 1.02049
# 16 1.49279 -0.492791
# These weights are combined from :
# Mdihadron0.38_
# Mdihadron0.88_
# Mdihadron1.22_
# Mdihadron0.55_
# Mdihadron0.72_
# Mdihadron1.05_
# FiledTree::~FiledTree()  tree name tree_postprocess 3045996 /work/clas12/users/gmat/CLAS12Analysis/data/rg-a/june8.root

# %% [markdown]
# Complete sPlots of the azimuthal angles

# %% [markdown]
# Setup fit manager

# %% [markdown]
# Load data and the sWeights from the above diphoton fits

# %%
c=ROOT.TCanvas("c","c",1200,1200)
ROOT.gStyle.SetOptStat(0)
c.Divide(2,2)
hp=ROOT.TH2F("hp","Signal Helicity=+1;phi_h",100,-3.1415,3.1415,100,-3.1415,3.1415)
hm=ROOT.TH2F("hm","Signal Helicity=-1;phi_R",100,-3.1415,3.1415,100,-3.1415,3.1415)
hp_bg=ROOT.TH2F("hp_bg","BG Helicity=+1;phi_h",100,-3.1415,3.1415,100,-3.1415,3.1415)
hm_bg=ROOT.TH2F("hm_bg","BG Helicity=-1;phi_R",100,-3.1415,3.1415,100,-3.1415,3.1415)
splot.DrawWeighted("phi_h:phi_R>>hp","Signal","helicity==1","goff");
splot.DrawWeighted("phi_h:phi_R>>hm","Signal","helicity==-1","goff");
splot.DrawWeighted("phi_h:phi_R>>hp_bg","BG","helicity==1","goff");
splot.DrawWeighted("phi_h:phi_R>>hm_bg","BG","helicity==-1","goff");
c.cd(1)
hp.Draw("colz")
c.cd(2)
hm.Draw("colz")
c.cd(3)
hp_bg.Draw("colz")
c.cd(4)
hm_bg.Draw("colz")
c.Draw()
# Out:
# Weights::Merge Merging Weights* in directory /w/hallb-scshelf2102/clas12/users/gmat/CLAS12Analysis/macros/dihadron_analysis/rg-a/outSplot
# Insert species BG 0 0
# Insert species Signal 1 0
# Weights::SortWeights() Clone tree to save
# Weights HSsWeights contains 1704314 events associated file is /w/hallb-scshelf2102/clas12/users/gmat/CLAS12Analysis/macros/dihadron_analysis/rg-a/outSplot//Tweights.root
# ID branch name : fidmerge
# Species are :
# BG
# Signal
# The first ten entries are :
# 1 -0.274613 1.27462
# 3 -0.179057 1.17906
# 4 -0.159467 1.15947
# 5 -0.145053 1.14505
# 6 1.01966 -0.0196664
# 6 -0.0864091 1.08641
# 8 1.60401 -0.604013
# 9 0.0320905 0.967912
# 10 -0.114136 1.11414
# 10 -0.176547 1.17655
# These weights are combined from :
# Mdihadron1.05_
# Mdihadron0.72_
# Mdihadron0.55_
# Mdihadron1.22_
#
# Mdihadron0.88_
# Mdihadron0.38_
# FiledTree::~FiledTree()  tree name tree_postprocess 3045996 /work/clas12/users/gmat/CLAS12Analysis/data/rg-a/june8.root
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c
# Warning in <TROOT::Append>: Replacing existing TH1: hp (Potential memory leak).
# Warning in <TROOT::Append>: Replacing existing TH1: hm (Potential memory leak).
# Warning in <TROOT::Append>: Replacing existing TH1: hp_bg (Potential memory leak).
# Warning in <TROOT::Append>: Replacing existing TH1: hm_bg (Potential memory leak).

# %%
c=ROOT.TCanvas("c","c",1200,1200)
#f=ROOT.TFile("../../../data/rg-a/june5.root","READ")
#f=ROOT.TFile("../../../data/rg-a/june5.root","READ")
#t=f.Get("tree_postprocess")
h1=ROOT.TH1F("h1","h1",100,0,0.4)
h2=ROOT.TH1F("h2","h2",100,0,0.4)
h3=ROOT.TH1F("h3","h3",100,0,0.4)
h1.SetLineColor(2)
h2.SetLineColor(1)
h3.SetLineColor(4)
splot.DrawWeighted("Mdiphoton>>h1","Signal","Mdihadron>0.3&&Mdihadron<0.8");
splot.DrawWeighted("Mdiphoton>>h2","BG","Mdihadron>0.3&&Mdihadron<0.8","same");
#t.Draw("Mdiphoton>>h3","","same")
c.Draw()
# Out:
# Weights::Merge Merging Weights* in directory /w/hallb-scshelf2102/clas12/users/gmat/CLAS12Analysis/macros/dihadron_analysis/rg-a/outSplot2
# Insert species BG 0 0
# Insert species Signal 1 0
# Weights::SortWeights() Clone tree to save
# Weights HSsWeights contains 1573 events associated file is /w/hallb-scshelf2102/clas12/users/gmat/CLAS12Analysis/macros/dihadron_analysis/rg-a/outSplot2//Tweights.root
# ID branch name : fidmerge
# Species are :
# BG
# Signal
# The first ten entries are :
# 3 -0.170348 1.17029
# 4 -0.278272 1.27829
# 6 -0.047938 1.04799
# 10 -0.317805 1.31782
# 11 -0.0828991 1.08291
# 12 -0.151516 1.15127
# 13 1.31209 -0.311977
# 17 -0.0905868 1.09061
# 18 -0.293169 1.29318
# 19 -0.117099 1.11715
# These weights are combined from :
# Mdihadron1.22_
# Mdihadron0.55_
# Mdihadron0.88_
# Mdihadron0.38_
# Mdihadron0.72_
# Mdihadron1.05_
# FiledTree::~FiledTree()  tree name tree_postprocess 2907 /work/clas12/users/gmat/CLAS12Analysis/data/rg-a/june5.root
# ******************************************************************************
# *Tree    :tree_postprocess: Tree created after all hipo events are filtered        *
# *Entries :     2907 : Total =          240191 bytes  File  Size =     143617 *
# *        :          : Tree compression factor =   1.30                       *
# ******************************************************************************
# *Br    0 :fid       : fid/I                                                  *
# *Entries :     2907 : Total  Size=      12195 bytes  File Size  =       4181 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=   2.80     *
# *............................................................................*
# *Br    1 :Mdiphoton : Mdiphoton/D                                            *
# *Entries :     2907 : Total  Size=      23861 bytes  File Size  =      22079 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=   1.06     *
# *............................................................................*
# *Br    2 :Mdihadron : Mdihadron/D                                            *
# *Entries :     2907 : Total  Size=      23861 bytes  File Size  =      22135 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=   1.05     *
# *............................................................................*
# *Br    3 :helicity  : helicity/F                                             *
# *Entries :     2907 : Total  Size=      12220 bytes  File Size  =       1444 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=   8.11     *
# *............................................................................*
# *Br    4 :phi_R     : phi_R/D                                                *
# *Entries :     2907 : Total  Size=      23841 bytes  File Size  =      22642 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=   1.03     *
# *............................................................................*
# *Br    5 :phi_h     : phi_h/D                                                *
# *Entries :     2907 : Total  Size=      23841 bytes  File Size  =      22626 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=   1.03     *
# *............................................................................*
# *Br    6 :th        : th/D                                                   *
# *Entries :     2907 : Total  Size=      23826 bytes  File Size  =      22105 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=   1.06     *
# *............................................................................*
# *Br    7 :z         : z/D                                                    *
# *Entries :     2907 : Total  Size=      23821 bytes  File Size  =      22031 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=   1.06     *
# *............................................................................*
# *Br    8 :polarization : polarization/F                                      *
# *Entries :     2907 : Total  Size=      12240 bytes  File Size  =        188 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=  62.34     *
# *............................................................................*
# *Br    9 :fidmerge  : fidmerge/I                                             *
# *Entries :     2907 : Total  Size=      12220 bytes  File Size  =       4186 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=   2.80     *
# *............................................................................*
# *Br   10 :BG        : BG/D                                                   *
# *Entries :     2907 : Total  Size=      23915 bytes  One basket in memory    *
# *Baskets :        0 : Basket Size=      32000 bytes  Compression=   1.00     *
# *............................................................................*
# *Br   11 :Signal    : Signal/D                                               *
# *Entries :     2907 : Total  Size=      23939 bytes  One basket in memory    *
# *Baskets :        0 : Basket Size=      32000 bytes  Compression=   1.00     *
# *............................................................................*
# ******************************************************************************
# *Tree    :tree_postprocess: Tree created after all hipo events are filtered        *
# *Entries :     2907 : Total =          240191 bytes  File  Size =     143617 *
# *        :          : Tree compression factor =   1.30                       *
# ******************************************************************************
# *Br    0 :fid       : fid/I                                                  *
# *Entries :     2907 : Total  Size=      12195 bytes  File Size  =       4181 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=   2.80     *
# *............................................................................*
# *Br    1 :Mdiphoton : Mdiphoton/D                                            *
# *Entries :     2907 : Total  Size=      23861 bytes  File Size  =      22079 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=   1.06     *
# *............................................................................*
# *Br    2 :Mdihadron : Mdihadron/D                                            *
# *Entries :     2907 : Total  Size=      23861 bytes  File Size  =      22135 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=   1.05     *
# *............................................................................*
# *Br    3 :helicity  : helicity/F                                             *
# *Entries :     2907 : Total  Size=      12220 bytes  File Size  =       1444 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=   8.11     *
# *............................................................................*
# *Br    4 :phi_R     : phi_R/D                                                *
# *Entries :     2907 : Total  Size=      23841 bytes  File Size  =      22642 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=   1.03     *
# *............................................................................*
# *Br    5 :phi_h     : phi_h/D                                                *
# *Entries :     2907 : Total  Size=      23841 bytes  File Size  =      22626 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=   1.03     *
# *............................................................................*
# *Br    6 :th        : th/D                                                   *
# *Entries :     2907 : Total  Size=      23826 bytes  File Size  =      22105 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=   1.06     *
# *............................................................................*
# *Br    7 :z         : z/D                                                    *
# *Entries :     2907 : Total  Size=      23821 bytes  File Size  =      22031 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=   1.06     *
# *............................................................................*
# *Br    8 :polarization : polarization/F                                      *
# *Entries :     2907 : Total  Size=      12240 bytes  File Size  =        188 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=  62.34     *
# *............................................................................*
# *Br    9 :fidmerge  : fidmerge/I                                             *
# *Entries :     2907 : Total  Size=      12220 bytes  File Size  =       4186 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=   2.80     *
# *............................................................................*
# *Br   10 :BG        : BG/D                                                   *
# *Entries :     2907 : Total  Size=      23915 bytes  One basket in memory    *
# *Baskets :        0 : Basket Size=      32000 bytes  Compression=   1.00     *
# *............................................................................*
# *Br   11 :Signal    : Signal/D                                               *
# *Entries :     2907 : Total  Size=      23939 bytes  One basket in memory    *
# *Baskets :        0 : Basket Size=      32000 bytes  Compression=   1.00     *
# *............................................................................*

# %%
f=ROOT.TFile("../../../data/rg-a/june5.root","READ")
t=f.Get("tree_postprocess")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-4a8e3c1b8430> in <module>
# ----> 1 f=ROOT.TFile("../../../data/rg-a/june5.root","READ")
#       2 t=f.Get("tree_postprocess")
#
# NameError: name 'ROOT' is not defined

# %%
fm = ROOT.FitManager()
fm.SetUp().SetOutDir(pwd+"/outObs1/");
fm.Data().LoadWeights("Signal",pwd+"/outSplot/Tweights.root");
# Out:
# Weights HSsWeights contains 1273843 events associated file is
# ID branch name : fid
# Species are :
# BG
# Signal
# The first ten entries are :
# 0 1.57251 -0.572518
# 0 -0.0757431 1.07574
# 0 1.19573 -0.195736
# 0 -0.148166 1.14816
# 0 -0.136741 1.13674
# 0 1.60782 -0.607822
# 0 -0.12464 1.12464
# 0 1.02881 -0.0288099
# 0 -0.141985 1.14198
# 0 -0.14833 1.14833
#   DataEvents::LoadWeights using Signal weights /w/hallb-scshelf2102/clas12/users/gmat/CLAS12Analysis/macros/dihadron_analysis/rg-a/outSplot/Tweights.root HSsWeights

# %%
f=ROOT.TFile("outSplot2/test.root","READ")
f.ls()
# Out:
# TFile**		outSplot2/test.root
#  TFile*		outSplot2/test.root

# %%
t.Print()
# Out:
# ---------------------------------------------------------------------------
# ReferenceError                            Traceback (most recent call last)
# <ipython-input-13-d8c797e27210> in <module>
# ----> 1 t.Print()
#
# ReferenceError: attempt to access a null-pointer

# %%
fm = ROOT.FitManager()
