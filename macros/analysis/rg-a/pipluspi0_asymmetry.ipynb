# %%
import ROOT
# %run toolkit/asym_tools.ipynb
# Out:
# Welcome to JupyROOT 6.22/06
# Matplotlib created a temporary config/cache directory at /tmp/matplotlib-vk75nygv because the default path (/home/jovyan/.cache/matplotlib) is not a writable directory; it is highly recommended to set the MPLCONFIGDIR environment variable to a writable directory, in particular to speed up the import of Matplotlib and to better support multiprocessing.

# %% [markdown]
# # Pi+Pi0
# /volatile/clas12/users/gmat/clas12analysis.sidis.data/rg-a/sept19_beta_0.02/
# RGA asymmetry analysis workflow in CLAS12Analysis, create plots from the asymmetry code
#
# ---
# Default file location

# %%
filedir = "/volatile/clas12/users/gmat/clas12analysis.sidis.data/rg-a/sept19_beta_0.02/"

# %%
# %run toolkit/asym_tools.ipynb
df = unpack_asym(filedir)

# %%
# %run toolkit/asym_tools.ipynb
plot_asym(df,"sept19_beta_0.02")
# Out:
# Creating directory 'plots/asym/sept19_beta_0.02'
# ------------------------------------------
# ------------------------------------------
# ------------------------------------------
# Directory 'plots/asym/sept19_beta_0.02' already exists...Continuing...
# ------------------------------------------
# ------------------------------------------
# ------------------------------------------
# Directory 'plots/asym/sept19_beta_0.02' already exists...Continuing...
