# %%
import ROOT
# %run toolkit/asym_tools.ipynb
# Out:
# Welcome to JupyROOT 6.22/06
# Matplotlib created a temporary config/cache directory at /tmp/matplotlib-h11rasbi because the default path (/home/jovyan/.cache/matplotlib) is not a writable directory; it is highly recommended to set the MPLCONFIGDIR environment variable to a writable directory, in particular to speed up the import of Matplotlib and to better support multiprocessing.

# %% [markdown]
# # Pi+Pi0 Asymmetry
# ---
# Author: Gregory Matousek
#
# Date: 9/6/2022
#
# Purpose: Following the RGA asymmetry analysis workflow in CLAS12Analysis, we create plots from the asymmetry code
#
# ---
# Default file location

# %%
filedir = "/volatile/clas12/users/gmat/clas12analysis.sidis.data/rg-a/aug23/"

# %%
# %run toolkit/asym_tools.ipynb
df = unpack_asym(filedir)

# %%
# %run toolkit/asym_tools.ipynb
plot_asym(df,"sept8")
# Out:
# Directory 'plots/asym/sept8' already exists...Continuing...
# ------------------------------------------
# ------------------------------------------
# ------------------------------------------
# Directory 'plots/asym/sept8' already exists...Continuing...
# ------------------------------------------
# ------------------------------------------
# ------------------------------------------
# Directory 'plots/asym/sept8' already exists...Continuing...
