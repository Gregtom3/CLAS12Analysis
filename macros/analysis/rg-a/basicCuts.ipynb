# %%
import ROOT
c = ROOT.TCanvas("c","c",600,600)
# Out:
# Welcome to JupyROOT 6.22/06

# %%
f = ROOT.TFile("/volatile/clas12/users/gmat/clas12analysis.sidis.data/rg-a-mc/sept19/merged_sept19.root","READ")
t = f.Get("tree_postprocess")

# %%
ROOT.gStyle.SetPalette(ROOT.kRainBow)
h1 = ROOT.TH1F("h1","h1",100,0,0.3)
h2 = ROOT.TH1F("h2","h2",100,0,0.3)
h3 = ROOT.TH1F("h3","h3",100,0,0.3)
h4 = ROOT.TH1F("h4","h4",100,0,0.3)
t.Draw("Mdiphoton>>h1","","PLC")
t.Draw("Mdiphoton>>h2","abs(beta1-beta2)<0.02","PLC same")
t.Draw("Mdiphoton>>h3","flag==1 && abs(beta1-beta2)>0.02","PLC same")
#t.Draw("Mdiphoton>>h4","parentPID1==111 && parentPID2==111 && abs(beta1-1)<0.02 && abs(beta2-1)<0.02","PLC same")

legend = ROOT.TLegend(0.2,0.6,0.7,0.8)
legend.AddEntry(h1,"Monte Carlo |#beta-1|<0.1")
legend.AddEntry(h2,"|#beta-1|<0.02")
legend.AddEntry(h3,"|#beta-1|<0.02 and same#pi^{0} parent")
#legend.AddEntry(h4,"|#beta-1|<0.02 and both parents#pi^{0}")
legend.Draw("same")
c.Draw()
# Out:
# Warning in <TFile::Append>: Replacing existing TH1: h1 (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: h2 (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: h3 (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: h4 (Potential memory leak).

# %%
ROOT.gStyle.SetPalette(ROOT.kRainBow)
h1 = ROOT.TH1F("h1","h1",100,0,0.3)
h2 = ROOT.TH1F("h2","h2",100,0,0.3)
h3 = ROOT.TH1F("h3","h3",100,0,0.3)
h4 = ROOT.TH1F("h4","h4",100,0,0.3)
t.Draw("Mdiphoton>>h1","","PLC")
t.Draw("Mdiphoton>>h2","abs(beta1-1)<0.02 && abs(beta2-1)<0.02","PLC same")
t.Draw("Mdiphoton>>h3","flag==1 && (abs(beta1-1)>0.02 || abs(beta2-1)>0.02)","PLC same")

legend = ROOT.TLegend(0.2,0.6,0.7,0.8)
legend.AddEntry(h1,"Monte Carlo |#beta-1|<0.1")
legend.AddEntry(h2,"|#beta-1|<0.02")
legend.AddEntry(h3,"|#beta-1|>0.02 and same#pi^{0} parent")
legend.Draw("same")
c.Draw()
# Out:
# Warning in <TFile::Append>: Replacing existing TH1: h1 (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: h2 (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: h3 (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: h4 (Potential memory leak).

# %%
ROOT.gStyle.SetPalette(ROOT.kRainBow)
h1 = ROOT.TH1F("h1","h1",100,0,0.3)
h2 = ROOT.TH1F("h2","h2",100,0,0.3)
h3 = ROOT.TH1F("h3","h3",100,0,0.3)
h4 = ROOT.TH1F("h4","h4",100,0,0.3)
t.Draw("Mdiphoton>>h1","","PLC")
t.Draw("Mdiphoton>>h2","cal_time_PCAL_1 > 147.5 && cal_time_PCAL_1 < 150 && cal_time_PCAL_2 > 147.5 && cal_time_PCAL_2 < 150","PLC same")
t.Draw("Mdiphoton>>h3","flag==1 && (abs(beta1-1)>0.02 || abs(beta2-1)>0.02)","PLC same")

legend = ROOT.TLegend(0.2,0.6,0.7,0.8)
legend.AddEntry(h1,"Monte Carlo |#beta-1|<0.1")
legend.AddEntry(h2,"|#beta-1|<0.02")
legend.AddEntry(h3,"|#beta-1|>0.02 and same#pi^{0} parent")
legend.Draw("same")
c.Draw()
# Out:
# Warning in <TFile::Append>: Replacing existing TH1: h1 (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: h2 (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: h3 (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: h4 (Potential memory leak).

# %%
var = "beta2-beta1"
t.Draw(var,"parentPID1==111 && parentPID2==111","PLC")
t.Draw(var,"parentPID1==-999 || parentPID2==-999","PLC same")



c.Draw()

# %%
var = "cal_time_PCAL_2"
t.Draw(var,"parentPID2==-999 && abs(beta2-1)<0.005","PLC")
t.Draw(var,"parentPID2==111 && abs(beta2-1)<0.005","PLC same")
c.Draw()

# %%
var = "beta2"
t.Draw(var,"parentPID2==-999","PLC")
t.Draw(var,"parentPID2==111","PLC same")
c.Draw()
