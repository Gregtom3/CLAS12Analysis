# %%
import ROOT
# %run ./toolkit/kin_tools.ipynb

# %%
print(draw_options())
# Out:
# ['x', 'y', 'Q2', 'W', 'Mmiss', 'Ptmiss', 'Ee', 'Pp', 'p_piplus', 'p_piminus', 'thetae', 'thetap', 'thetapiplus', 'thetapiminus', 'thetap_predict', 'phie', 'phip', 'vze', 'vzp', 'vzpiplus', 'vzpiminus', 'pte', 'p_e:theta_e', 'p_p:theta_p', 'Dy', 'Dy:xB', 'Mdihadron', 'Ptmiss', 'Mmiss_p', 'chi2_piplus', 'chi2_piminus', 'chi2_p']

# %% [markdown]
# # Exclusive Rho Data
# ---
# All the NH3 data together

# %%
create_kin_plots(rootdir_data = "/volatile/clas12/users/gmat/clas12analysis.sidis.data/rgc/sidisdvcs/exclusive_pipiproton_test8.3.2/",
                     rootdir_MC = "/volatile/clas12/users/gmat/clas12analysis.sidis.data/rgc/MC/exclusive_pipiproton_test/merged_run.root",
                     target = "NH3",
                     runMin = 16000,
                     runMax = 18000,
                     runList = [],
                     plotList = ["x","y","Q2","W",
                                 "Ee","Pp","p_piplus","p_piminus",
                                 "thetae","thetap","thetapiplus","thetapiminus",
                                 "Mdihadron","Mmiss","Ptmiss","Mmiss_p",
                                 "vze","vzp","vzpiplus","vzpiminus",
                                 "phie","chi2_piplus","chi2_piminus","chi2_p"],
                     outdir = "oct12_all_exclusive")
# Out:
# Creating directory 'plots/kin/oct12_all_exclusive'
# [16720, 16746, 17098, 16990, 16728, 17088, 16762, 17095, 17162, 16772, 17085, 16681, 17102, 16983, 17093, 17076, 16770, 16768, 16759, 16683, 17015, 16744, 16717, 17144, 16992, 16726, 16750, 17019, 17001, 17092]
# []
# x_{B} 0.2167263973376748
# y 0.6225437865926337
# Q^{2} [GeV^{2}] 2.6022385841749074
# W [GeV] 3.2083567409691747
# E(e') [GeV] 3.9914098105983262
# P(p') [GeV] 1.3518639071063425
# p(#pi^{+}) [GeV] 1.1904303475792155
# p(#pi^{-}) [GeV] 1.1367612238043223
# #theta(e') 15.460681775652297
# #theta(p) 29.97151190144065
# #theta(#pi^{+}) 30.115346786861807
# #theta(#pi^{-}) 39.08692881998738
# Dihadron Mass [GeV] 0.7839531486477741
# M_{miss} [GeV] 0.4340282392930449
# Pt_{miss} [GeV] 0.6240087976706817
# Proton Mass (Missing) [GeV] 1.3566815756767567
# Vertex z(e') [cm] -3.454381028480344
# Vertex z(p) [cm] -4.096823320162639
# Vertex z(#pi^{+}) [cm] -4.071040790472013
# Vertex z(#pi^{-}) [cm] -3.062971790500396
# ...

# %% [markdown]
# All the HBT NH3 data together

# %%
create_kin_plots(rootdir_data = "/volatile/clas12/users/gmat/clas12analysis.sidis.data/rgc/sidisdvcs/exclusive_pipiproton_test/",
                     rootdir_MC = "/volatile/clas12/users/gmat/clas12analysis.sidis.data/rgc/MC/exclusive_pipiproton_test/merged_run.root",
                     target = "NH3",
                     runMin = 16000,
                     runMax = 18000,
                     runList = [],
                     plotList = ["x","y","Q2","W",
                                 "Ee","Pp","p_piplus","p_piminus",
                                 "thetae","thetap","thetapiplus","thetapiminus",
                                 "Mdihadron","Mmiss","Ptmiss","Mmiss_p",
                                 "vze","vzp","vzpiplus","vzpiminus",
                                 "phie","chi2_piplus","chi2_piminus","chi2_p"],
                     outdir = "oct3_HBT_exclusive",
                     cookType="HBT")
# Out:
# Directory 'plots/kin/oct3_HBT_exclusive' already exists...Continuing...
# [17073, 16758, 16769, 16996, 16771, 16982, 16765, 17067, 16761, 17093, 17000, 16755, 16987, 17097, 16993, 17010, 17014, 17025, 17002, 17095, 16753, 16989, 17016, 16995, 17027, 17069, 17098, 16767, 16984]
# []
# x_{B} 0.2136287102363644
# y 0.6461627663230672
# Q^{2} [GeV^{2}] 2.687280345623007
# W [GeV] 3.272627567873156
# E(e') [GeV] 3.7433958977444592
# P(p') [GeV] 1.4408568561812276
# p(#pi^{+}) [GeV] 1.3182464032325723
# p(#pi^{-}) [GeV] 1.3145743852033962
# #theta(e') 16.0947887310411
# #theta(p) 21.440480756929425
# #theta(#pi^{+}) 20.575648744997036
# #theta(#pi^{-}) 28.161232765098376
# Dihadron Mass [GeV] 0.7249593028415982
# M_{miss} [GeV] 0.5971351409620275
# Pt_{miss} [GeV] 0.5724509089644707
# Proton Mass (Missing) [GeV] 1.4975671708781868
# Vertex z(e') [cm] -3.338449122786189
# Vertex z(p) [cm] -3.7156124848767087
# Vertex z(#pi^{+}) [cm] -3.5966603628401264
# ...

# %% [markdown]
# All the TBT NH3 data together

# %%
create_kin_plots(rootdir_data = "/volatile/clas12/users/gmat/clas12analysis.sidis.data/rgc/sidisdvcs/exclusive_pipiproton_test/",
                     rootdir_MC = "/volatile/clas12/users/gmat/clas12analysis.sidis.data/rgc/MC/exclusive_pipiproton_test/merged_run.root",
                     target = "NH3",
                     runMin = 16000,
                     runMax = 18000,
                     runList = [],
                     plotList = ["x","y","Q2","W",
                                 "Ee","Pp","p_piplus","p_piminus",
                                 "thetae","thetap","thetapiplus","thetapiminus",
                                 "Mdihadron","Mmiss","Ptmiss","Mmiss_p",
                                 "vze","vzp","vzpiplus","vzpiminus",
                                 "phie","chi2_piplus","chi2_piminus","chi2_p"],
                     outdir = "oct3_TBT_exclusive",
                     cookType="TBT")
# Out:
# Directory 'plots/kin/oct3_TBT_exclusive' already exists...Continuing...
# [17020, 16682, 16713, 16736, 16692, 16748, 16732, 16727, 16712, 16676, 16723, 16729, 16659, 16710, 16674, 17085, 16743, 16685, 16715, 16671, 16711, 17084, 16709, 16742, 16688, 16679, 16665, 16730, 16752, 16719]
# []
# x_{B} 0.2173749955163841
# y 0.6187225648604737
# Q^{2} [GeV^{2}] 2.591335802273229
# W [GeV] 3.197927499403834
# E(e') [GeV] 4.0331646518346504
# P(p') [GeV] 1.3401880033695384
# p(#pi^{+}) [GeV] 1.1907157064696328
# p(#pi^{-}) [GeV] 1.1229402964912625
# #theta(e') 15.341079544532962
# #theta(p) 30.435286268130408
# #theta(#pi^{+}) 30.037898019850335
# #theta(#pi^{-}) 39.46266617768661
# Dihadron Mass [GeV] 0.7827468395650412
# M_{miss} [GeV] 0.41446620075729695
# Pt_{miss} [GeV] 0.6070021541163607
# Proton Mass (Missing) [GeV] 1.359610934208262
# Vertex z(e') [cm] -3.561324565686113
# Vertex z(p) [cm] -4.260865243884588
# Vertex z(#pi^{+}) [cm] -4.2701235892975395
# ...

# %% [markdown]
# All the FTon TBT NH3 data together

# %%
create_kin_plots(rootdir_data = "/volatile/clas12/users/gmat/clas12analysis.sidis.data/rgc/sidisdvcs/exclusive_pipiproton_test/",
                     rootdir_MC = "/volatile/clas12/users/gmat/clas12analysis.sidis.data/rgc/MC/exclusive_pipiproton_test/merged_run.root",
                     target = "NH3",
                     runMin = 16000,
                     runMax = 18000,
                     runList = [],
                     plotList = ["x","y","Q2","W",
                                 "Ee","Pp","p_piplus","p_piminus",
                                 "thetae","thetap","thetapiplus","thetapiminus",
                                 "Mdihadron","Mmiss","Ptmiss","Mmiss_p",
                                 "vze","vzp","vzpiplus","vzpiminus",
                                 "phie","chi2_piplus","chi2_piminus","chi2_p"],
                     outdir = "oct3_TBT_FTon_exclusive",
                     cookType="TBT",
                     ft="on")
# Out:
# Directory 'plots/kin/oct3_TBT_FTon_exclusive' already exists...Continuing...
# [16682, 16713, 16736, 16692, 16748, 16732, 16727, 16712, 16676, 16723, 16729, 16659, 16710, 16674, 16743, 16685, 16715, 16671, 16711, 16709, 16742, 16688, 16679, 16665, 16730, 16752, 16719]
# []
# x_{B} 0.21779060114336696
# y 0.6166778074157626
# Q^{2} [GeV^{2}] 2.587469890058802
# W [GeV] 3.1923041303855815
# E(e') [GeV] 4.055653084238087
# P(p') [GeV] 1.3376024758353755
# p(#pi^{+}) [GeV] 1.199919205435292
# p(#pi^{-}) [GeV] 1.12450923901955
# #theta(e') 15.271605363622843
# #theta(p) 30.514255496368076
# #theta(#pi^{+}) 29.189266525218798
# #theta(#pi^{-}) 38.93870764874742
# Dihadron Mass [GeV] 0.777850912074677
# M_{miss} [GeV] 0.4134861683960807
# Pt_{miss} [GeV] 0.5869321546908592
# Proton Mass (Missing) [GeV] 1.3732148514717983
# Vertex z(e') [cm] -3.7658574740303647
# Vertex z(p) [cm] -4.470365793070837
# Vertex z(#pi^{+}) [cm] -4.506963555906075
# Vertex z(#pi^{-}) [cm] -3.4676499002750316
# ...

# %% [markdown]
# All the FToff TBT NH3 data together

# %%
create_kin_plots(rootdir_data = "/volatile/clas12/users/gmat/clas12analysis.sidis.data/rgc/sidisdvcs/exclusive_pipiproton_test/",
                     rootdir_MC = "/volatile/clas12/users/gmat/clas12analysis.sidis.data/rgc/MC/exclusive_pipiproton_test/merged_run.root",
                     target = "NH3",
                     runMin = 16000,
                     runMax = 18000,
                     runList = [],
                     plotList = ["x","y","Q2","W",
                                 "Ee","Pp","p_piplus","p_piminus",
                                 "thetae","thetap","thetapiplus","thetapiminus",
                                 "Mdihadron","Mmiss","Ptmiss","Mmiss_p",
                                 "vze","vzp","vzpiplus","vzpiminus",
                                 "phie","chi2_piplus","chi2_piminus","chi2_p"],
                     outdir = "oct3_TBT_FToff_exclusive",
                     cookType="TBT",
                     ft="off")
# Out:
# Directory 'plots/kin/oct3_TBT_FToff_exclusive' already exists...Continuing...
# [17020, 17085, 17084]
# []
# x_{B} 0.21625022643999348
# y 0.6242563730086046
# Q^{2} [GeV^{2}] 2.601798437440379
# W [GeV] 3.2131462616012705
# E(e') [GeV] 3.972303315545245
# P(p') [GeV] 1.3471872027020706
# p(#pi^{+}) [GeV] 1.1657238149520612
# p(#pi^{-}) [GeV] 1.1186657059989125
# #theta(e') 15.529102076071377
# #theta(p) 30.221255935800677
# #theta(#pi^{+}) 32.36143320370551
# #theta(#pi^{-}) 40.91041143631277
# Dihadron Mass [GeV] 0.7962800729020806
# M_{miss} [GeV] 0.41745009733802374
# Pt_{miss} [GeV] 0.6620125993208307
# Proton Mass (Missing) [GeV] 1.3192912092466529
# Vertex z(e') [cm] -3.007559368007314
# Vertex z(p) [cm] -3.6904559519921807
# Vertex z(#pi^{+}) [cm] -3.622299285349994
# Vertex z(#pi^{-}) [cm] -2.6247432830081676
# #phi(e') -7.408172066880368
# #chi^{2}_{track}(#pi^{+}) -0.4810086053011809
# #chi^{2}_{track}(#pi^{-}) -0.6161187847430761
# ...

# %% [markdown]
# # Carbon
# ---

# %%
create_kin_plots(rootdir_data = "/volatile/clas12/users/gmat/clas12analysis.sidis.data/rgc/sidisdvcs/exclusive_pipiproton_test/",
                     rootdir_MC = "/volatile/clas12/users/gmat/clas12analysis.sidis.data/rgc/MC/exclusive_pipiproton_test/merged_run.root",
                     target = "C",
                     runMin = 16000,
                     runMax = 18000,
                     runList = [],
                     plotList = ["x","y","Q2","W",
                                 "Ee","Pp","p_piplus","p_piminus",
                                 "thetae","thetap","thetapiplus","thetapiminus",
                                 "Mdihadron","Mmiss","Ptmiss","Mmiss_p",
                                 "vze","vzp","vzpiplus","vzpiminus",
                                 "phie","chi2_piplus","chi2_piminus","chi2_p"],
                     outdir = "oct3_all_C_FTon_exclusive",
                     ft="on")
# Out:
# Creating directory 'plots/kin/oct3_all_C_FTon_exclusive'
# [16292]
# []
# x_{B} 0.21398880090594238
# y 0.6238607773191347
# Q^{2} [GeV^{2}] 2.573142055996359
# W [GeV] 3.216635321786662
# E(e') [GeV] 3.973904686586897
# P(p') [GeV] 1.2997174868908157
# p(#pi^{+}) [GeV] 1.1531728405507953
# p(#pi^{-}) [GeV] 1.0859250224219108
# #theta(e') 15.460437833177908
# #theta(p) 32.45914811950349
# #theta(#pi^{+}) 30.851546547859375
# #theta(#pi^{-}) 40.43181470055511
# Dihadron Mass [GeV] 0.7788668559764237
# M_{miss} [GeV] 0.3847626199473155
# Pt_{miss} [GeV] 0.6294144059274739
# Proton Mass (Missing) [GeV] 1.3527378979420024
# Vertex z(e') [cm] -3.8137357331851773
# Vertex z(p) [cm] -4.478457403491944
# Vertex z(#pi^{+}) [cm] -4.469528234475561
# Vertex z(#pi^{-}) [cm] -3.4860594924746544
# #phi(e') -9.393234555061468
# #chi^{2}_{track}(#pi^{+}) -0.30825514623111133
# #chi^{2}_{track}(#pi^{-}) -0.2523947367438484
# #chi^{2}_{track}(#pi^{+}) 0.05742412672570582

# %%
create_kin_plots(rootdir_data = "/volatile/clas12/users/gmat/clas12analysis.sidis.data/rgc/sidisdvcs/exclusive_pipiproton_test/",
                     rootdir_MC = "/volatile/clas12/users/gmat/clas12analysis.sidis.data/rgc/MC/exclusive_pipiproton_test/merged_run.root",
                     target = "C",
                     runMin = 16000,
                     runMax = 18000,
                     runList = [],
                     plotList = ["x","y","Q2","W",
                                 "Ee","Pp","p_piplus","p_piminus",
                                 "thetae","thetap","thetapiplus","thetapiminus",
                                 "Mdihadron","Mmiss","Ptmiss","Mmiss_p",
                                 "vze","vzp","vzpiplus","vzpiminus",
                                 "phie","chi2_piplus","chi2_piminus","chi2_p"],
                     outdir = "oct3_all_C_FToff_exclusive",
                     ft="off")
# Out:
# Creating directory 'plots/kin/oct3_all_C_FToff_exclusive'
# [16878]
# []
# x_{B} 0.21233457417550222
# y 0.6321024886678349
# Q^{2} [GeV^{2}] 2.584859614972925
# W [GeV] 3.2392272633271895
# E(e') [GeV] 3.88908921137221
# P(p') [GeV] 1.2982179629480735
# p(#pi^{+}) [GeV] 1.1209175089739807
# p(#pi^{-}) [GeV] 1.097306720774766
# #theta(e') 15.7341457857073
# #theta(p) 32.432909053816736
# #theta(#pi^{+}) 34.93871094740739
# #theta(#pi^{-}) 42.81971001406157
# Dihadron Mass [GeV] 0.8115249085901529
# M_{miss} [GeV] 0.3923403933500378
# Pt_{miss} [GeV] 0.7480340222304404
# Proton Mass (Missing) [GeV] 1.2763332329392616
# Vertex z(e') [cm] -2.916176375393298
# Vertex z(p) [cm] -3.6413765815003196
# Vertex z(#pi^{+}) [cm] -3.494469934105236
# Vertex z(#pi^{-}) [cm] -2.6481519694927633
# #phi(e') -6.775238802338642
# #chi^{2}_{track}(#pi^{+}) -0.2642899415932142
# #chi^{2}_{track}(#pi^{-}) -0.33834442462011566
# #chi^{2}_{track}(#pi^{+}) 0.22816107559342916

# %%
_=create_kin_plots(rootdir_data = "/volatile/clas12/users/gmat/clas12analysis.sidis.data/rgc/sidisdvcs/exclusive_pipiproton_test8.3.2/",
                     rootdir_MC = "/volatile/clas12/users/gmat/clas12analysis.sidis.data/rgc/MC/exclusive_pipiproton_test/merged_run.root",
                     target = "NH3",
                     runMin = 16000,
                     runMax = 18000,
                     runList = [],
                     plotList = ["x","y","Q2","W",
                                 "Ee","Pp","p_piplus","p_piminus",
                                 "thetae","thetap","thetapiplus","thetapiminus",
                                 "Mdihadron","Mmiss","Ptmiss","Mmiss_p",
                                 "vze","vzp","vzpiplus","vzpiminus",
                                 "phie","chi2_piplus","chi2_piminus","chi2_p"],
                     outdir = "test",
                     cookType="TBT")
# Out:
# Directory 'plots/kin/test' already exists...Continuing...
#       Run    beamE  beamCurrent    Nevents  eventRate  isValid      Tpol  HWP  \
# 0   16300  10547.3     3.928270   73623193   1564.270     True -0.002764    1
# 1   16720  10547.3     3.676670   32749719    127.441     True  0.566081    0
# 2   17138  10556.3     7.835800  100677458   1955.650     True  0.001531    1
# 3   16746  10547.3     0.007945   65867687   1793.640     True -0.507830    1
# 4   17098  10556.3     5.930260   31483334   1008.960     True -0.664892    0
# 5   16990  10547.3     7.646660  100248071    397.895    False  0.669132    1
# 6   16979  10547.3    -0.001545    5038509    821.794     True  0.004181    0
# 7   16728  10547.3     3.848600   57919646    255.500     True -0.512262    0
# 8   17088  10556.3     0.454866   52373900    365.796     True  0.732985    1
# 9   16762  10547.3     3.664090   69187287   1203.280     True -0.508841    0
# ...
